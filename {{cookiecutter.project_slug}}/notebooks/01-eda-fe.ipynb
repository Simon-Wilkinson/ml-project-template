# %% [markdown]
# # 01 — EDA + Feature Engineering
#
# **Goal:** understand the data, try transforms, arrive at a feature set.
# **Output:** keeper transforms graduated into `src/{{ cookiecutter.package_name }}/features.py`.
#
# Run this notebook top-to-bottom before committing.

# %% [markdown]
# ## Setup

# %%
import sys
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

sys.path.insert(0, str(Path("..").resolve()))
from {{ cookiecutter.package_name }} import config, data

sns.set_theme(style="whitegrid")
# %matplotlib inline

# %% [markdown]
# ## Load raw data

# %%
# df = data.load_raw()
# df.head()

# %% [markdown]
# ## Shape, dtypes, missing values

# %%
# print(df.shape)
# print(df.dtypes)
# df.isnull().sum().sort_values(ascending=False)

# %% [markdown]
# ## Descriptive statistics

# %%
# df.describe()

# %% [markdown]
# ## Target distribution

# %%
# target_col = "target"  # replace
# df[target_col].hist(bins=40)
# plt.title("Target distribution")
# plt.show()

# %% [markdown]
# ## Feature distributions

# %%
# df.hist(figsize=(12, 8))
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## Correlations

# %%
# corr = df.corr(numeric_only=True)
# sns.heatmap(corr, annot=True, fmt=".2f", cmap="coolwarm")
# plt.show()

# %% [markdown]
# ## Feature engineering
#
# Try transforms here.  Once a transform earns its place, graduate it into
# `src/{{ cookiecutter.package_name }}/features.py` as part of `build_pipeline()`.

# %%
# Add / transform features here
# e.g. df["log_x"] = np.log1p(df["x"])

# %% [markdown]
# ## Graduation check
#
# Once you've built `build_pipeline()`, verify it is importable and runs here.

# %%
from {{ cookiecutter.package_name }}.features import build_pipeline

pipeline = build_pipeline()
print("Pipeline:\n", pipeline)
